# %% [markdown]
# # Model Comparison
# This notebook compares the baseline Random Forest model, the tuned Random Forest model, and the XGBoost model trained on the employee attrition dataset.

# %%
import json
from pathlib import Path

root = Path.cwd()
if root.name == 'notebooks':
    root = root.parent

model_info_path = root / 'models' / 'model_info.json'
with open(model_info_path, 'r', encoding='utf-8') as f:
    model_info = json.load(f)

model_info

# %% [markdown]
# ## Comparison summary
# The JSON output above contains the evaluation metrics for each candidate model and identifies the selected best model.
